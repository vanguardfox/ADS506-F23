# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader.data as web
import yfinance as yf
import datetime
from datetime import date
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import ParameterGrid
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing, Holt, seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tools.eval_measures import rmse, meanabs
# %matplotlib inline

# %% [markdown]
# Time Series Eval Metrics Method

# %%
def ts_eval_metrics(y_true, y_pred):
    print('Time Series Evaluation Metrics')
    print(f'MSE = {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE = {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE = {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE = {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'r2 = {metrics.r2_score(y_true, y_pred)}', end='\n\n')

# %%
aapl = yf.Ticker("SPY")

# %% [markdown]
# ### Plot an initial time series
# ##### Reference
# ##### Chaudhari, S. (2021). Stationarity in time series analysis explained using Python. Mathematics and Econometrics. https://blog.quantinsti.com/stationarity

# %%
plt.style.use('tableau-colorblind10') #https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.figure(figsize=(12, 6))
close = aapl.history(period='24mo')['Close']
plt.plot(close)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('AAPL Historical Price')
plt.show()

# %% [markdown]
# ## Check stationarity

# %% [markdown]
# ### Split Price into halves for statistical analysis

# %%
X = close.copy()
split = round(len(X)/2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
mean_percent_diff = (mean2 - mean1) / mean1 * 100
var1, var2 = X1.var(), X2.var()
var_percent_diff = (var2 - var1) / var1 * 100
print('mean1=%f, mean2=%3f, mean_percent_diff=%f' % (mean1, mean2, mean_percent_diff))
print('variance1=%f, variance2=%f, var_percent_diff=%f' % (var1, var2, var_percent_diff))
# Out:
# mean1=410.823165, mean2=414.278171, mean_percent_diff=0.840996
# variance1=1017.748832, variance2=527.935105, var_percent_diff=-48.127172

# %% [markdown]
# ### Augmented Dickey-Fuller Test
# ##### Check for stationarity where H0 = time series !stationary; H1 = time series = stationary
# ##### If p-value <= .05 or abs(test statistic)>critical value, reject H0

# %%
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
print(result[4])
# Out:
# ADF Statistic: -2.203446
# p-value: 0.204997
# Critical Values:
# {'1%': -3.4434437319767452, '5%': -2.8673146875484368, '10%': -2.569845688481135}

# %% [markdown]
# ##### P-value > .05; therefore, time series is not stationary (as expected).
# ##### abs(ADF Statistic) < abs(critical value) -> fail to reject H0
# ##### Therefore: Time series is not stationary for p-values .01, .05, and .1

# %% [markdown]
# ### Kwiatkowski-Phillips-Schmidt-Shin test
# ##### KPSS is opposite of ADF where H0 = time series = stationary; H1 = time series !stationary
# ##### If p-value <= .05 || abs(KPSS test statistic)>critical value -> reject H0 -> therefore, !stationary

# %%
result = kpss(X)
print(result)
print('KPSS Test Statistic: %.2f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
print(result[3])
# Out:
# (0.8047069129733099, 0.01, 12, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})
# KPSS Test Statistic: 0.80
# p-value: 0.010000
# Critical Values:
# {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# /Users/johnvincent/Library/r-miniconda-arm64/envs/r-reticulate/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# ##### P-value < .05; therefore, not stationary

# %% [markdown]
# ### Transform into stationary series

# %%
X['Difference'] = X.diff()
plt.figure(figsize=(12,6))
plt.plot(X['Difference'])
plt.title('First Order Differenced Series')
plt.xlabel('Time')
plt.ylabel('Difference')
plt.show()

# %%
result = adfuller(X.Difference.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
print(result[4])
# Out:
# ADF Statistic: -21.970217
# p-value: 0.000000
# Critical Values:
# {'1%': -3.443470002903981, '5%': -2.867326248740681, '10%': -2.569851849873108}

# %% [markdown]
# (ADF) P-value < .05; therefore, AAPL price series is a difference-stationary series.

# %% [markdown]
# ### Smoothing Methods
# ##### Reference
# https://machinelearningmastery.com/exponential-smoothing-for-time-series-forecasting-in-python/

# %% [markdown]
# ### Triple Exponential Smoothing
# ##### Use because we assume these time series have level, trends, seasonality, and noise
# ##### https://machinelearningmastery.com/how-to-grid-search-triple-exponential-smoothing-for-time-series-forecasting-in-python/

# %%
# Using method from Brownlee, J. (2020).
def exp_smoothing_forecast(history, config):
    t,d,s,p,b,r = config
    # define model model
    history = array(history)
    model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
    # fit model
    model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
    # make one step forecast
    yhat = model_fit.predict(len(history), len(history))
    return yhat[0]

# %% [markdown]
# ## Time Series Prediction
# ### Data partition
# #### 2 years train; last 1 year validation

# %%
close = aapl.history(period='36mo')['Close']
print(len(close))
close_train = close.iloc[:506]
close_valid = close.iloc[-260:]
# Out:
# 755

# %% [markdown]
# ## Simple Exponential forecaster
# ### Plot an initial time series
# ##### Reference: Module 1

# %%
# Forecast 12 months ahead
ses_model = SimpleExpSmoothing(close_train).fit()

ses_pred = ses_model.forecast(steps=260)
ses_eval_metrics = ts_eval_metrics(close_valid, ses_pred)
# Out:
# /Users/johnvincent/Library/r-miniconda-arm64/envs/r-reticulate/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/johnvincent/Library/r-miniconda-arm64/envs/r-reticulate/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
plt.figure(figsize=(12, 6))
plt.plot(close_train, label='Training Data', color='blue')
plt.plot(close_valid, label='Actual Data (Validation)', color='green', linestyle='--')
plt.plot(close_valid.index, ses_pred, label='SES Forecast', color='red')

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price - Training Data, Actual Data, and SES Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
#impute
close = close.ffill()
close = close.asfreq('D')

decomposition = seasonal_decompose(close, model='additive')
decomposition.plot()
plt.show()

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot autocorrelation
plot_acf(close, lags=30)  # Adjust the number of lags as needed
plt.show()

# %%
aes_model = ExponentialSmoothing(close_train, trend='add', seasonal='add', seasonal_periods=7, initialization_method='estimated')
aes_model = aes_model.fit(smoothing_level=0.1, smoothing_slope=0.1)

aes_pred = aes_model.forecast(steps=260)
aes_eval_metrics = ts_eval_metrics(close_valid, aes_pred)
print(aes_eval_metrics)
# Out:
# Time Series Evaluation Metrics
# MSE = 7214.862885413425
# MAE = 71.47691769816765
# RMSE = 84.94034898335082
# MAPE = 0.1691822350746753
# r2 = -11.901575056077222
#
# None
# C:\Users\rkartawi\AppData\Local\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\rkartawi\AppData\Local\Temp\ipykernel_11772\1752438999.py:2: FutureWarning: the 'smoothing_slope' keyword is deprecated, use 'smoothing_trend' instead.
#   aes_model = aes_model.fit(smoothing_level=0.1, smoothing_slope=0.1)
# C:\Users\rkartawi\AppData\Local\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\rkartawi\AppData\Local\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
plt.figure(figsize=(12, 6))
plt.plot(close_train, label='Training Data', color='blue')
plt.plot(close_valid, label='Actual Data (Validation)', color='green', linestyle='--')
plt.plot(close_valid.index, aes_pred, label='AES Forecast', color='red')

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price - Training Data, Actual Data, and AES Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
aapl.income_stmt
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
aapl.quarterly_income_stmt
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
aapl.balance_sheet
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
aapl.quarterly_cashflow
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
aapl.major_holders
# Out:
#                 0                1
# 0  Previous Close           430.76
# 1            Open           433.14
# 2             Bid     435.23 x 900
# 3             Ask    435.17 x 1300
# 4     Day's Range  433.01 - 436.29
# 5   52 Week Range  370.00 - 459.44
# 6          Volume        100024745
# 7     Avg. Volume         83155864

# %%
aapl.institutional_holders
# Out:
#                         0           1
# 0              Net Assets     400.96B
# 1                     NAV      430.68
# 2          PE Ratio (TTM)       21.90
# 3                   Yield       1.52%
# 4  YTD Daily Total Return      13.90%
# 5       Beta (5Y Monthly)        1.00
# 6     Expense Ratio (net)       0.09%
# 7          Inception Date  1993-01-22

# %%
aapl.mutualfund_holders

# %%
aapl.news
# Out:
# [{'uuid': '5dbbc2a4-ba53-45f1-b617-4119c3765df2',
#   'title': 'Stock market news today: Stocks rise as jobs growth cools more than expected',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-today-stocks-rise-as-jobs-growth-cools-more-than-expected-133705314.html',
#   'providerPublishTime': 1699042040,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/XVZMrgaEeqlbgRQ6B9rFAw--~B/aD00MDAwO3c9NjAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-11/ec449170-79cc-11ee-97f3-6d9feb44432d',
#      'width': 6000,
#      'height': 4000,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ZlWVoDQ5PrGH2QI3NsseYw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-11/ec449170-79cc-11ee-97f3-6d9feb44432d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', '^IXIC', 'QQQ', 'SPY', '^GSPC']},
#  {'uuid': '69ba814a-f537-43a3-bfeb-d2775d18ba15',
#   'title': 'Goldbugs may need to keep waiting for $3,000: Morning Brief',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/goldbugs-may-need-to-keep-waiting-for-3000-morning-brief-091310124.html',
#   'providerPublishTime': 1699002790,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/vrWVFvnrIDcZGwLLt_DSZA--~B/aD0xMDI0O3c9MTAyNDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e8705060-79aa-11ee-99bd-c8ab56a3f5c7',
#      'width': 1024,
#      'height': 1024,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/i9IxzU0KX8qDgi.glngn2Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e8705060-79aa-11ee-99bd-c8ab56a3f5c7',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^IRX',
#    '^DJI',
#    '^TNX',
#    'GC=F',
#    '^RUT',
#    'DX-Y.NYB',
#    'GCZ23.CMX',
#    'SPY',
#    'GLD',
#    '^TYX',
#    'DBC',
#    'TLT',
#    'UUP',
#    '^IXIC',
#    '^GSPC',
#    'ZG=F',
#    'CL=F']},
#  {'uuid': '0204f7f7-b536-47d8-bc9a-d0cfcf806ba1',
#   'title': 'Stock market news today: Dow rises more than 500 points as investors bet on end to Fed hikes',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-today-dow-rises-more-than-500-points-as-investors-bet-on-end-to-fed-hikes-180535435.html',
#   'providerPublishTime': 1698948335,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/vRoKMXP3Biwtp85SgMcEiQ--~B/aD0xNzEwO3c9MjQxNzthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-11/f80d2690-7975-11ee-aeff-2d2d3e799be6',
#      'width': 2417,
#      'height': 1710,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/J7QM3ZBZ9BL.4YFC39d.sQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-11/f80d2690-7975-11ee-aeff-2d2d3e799be6',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', '^IXIC', 'SPY', 'QQQ', '^GSPC']},
#  {'uuid': '740ffd26-12fb-3d12-9f13-59f8c6e27d0f',
#   'title': 'State Street Global Advisors slashes fees on flagship European ETF',
#   'publisher': 'Financial Times',
#   'link': 'https://finance.yahoo.com/m/740ffd26-12fb-3d12-9f13-59f8c6e27d0f/state-street-global-advisors.html',
#   'providerPublishTime': 1698901254,
#   'type': 'STORY',
#   'relatedTickers': ['^GSPC', 'SPY', 'STT']},
#  {'uuid': 'a41d8982-6e01-4eb9-8b35-0db51ab28345',
#   'title': 'Stock market news today: Stocks rally, tech surges after Fed leaves rates unchanged',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-today-stocks-rally-tech-surges-after-fed-leaves-rates-unchanged-200646451.html',
#   'providerPublishTime': 1698869206,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gU9MtIcAX.CnKaHO4gAydg--~B/aD0zODE3O3c9NTcyNjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-images/2019-06/a5329650-98d6-11e9-9e5f-d11c6cd1d3b6',
#      'width': 5726,
#      'height': 3817,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/3KBKVFX3vNnjeANsK1tAdA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-images/2019-06/a5329650-98d6-11e9-9e5f-d11c6cd1d3b6',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', '^IXIC', 'QQQ', '^DJI', 'SPY']},
#  {'uuid': 'c46a6c31-7643-3cc1-9b93-efc1613554bb',
#   'title': 'Stock options bets on volatility around macro events are finally paying off',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/stock-options-bets-volatility-around-161023624.html',
#   'providerPublishTime': 1698855023,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/HK8q0yn7cDUnOYsnJGlcKw--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/445bb15fa702fd5cf65d3d9677f9477c',
#      'width': 800,
#      'height': 533,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/bsqwbyD.OwqUVL.5BAjnfw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/445bb15fa702fd5cf65d3d9677f9477c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['SPY']},
#  {'uuid': '9d28efc2-f7bd-36f0-bbd0-13601b3bda9a',
#   'title': "5 Stocks in ETF That Defied S&P 500's Longest Slide Since 2020",
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/5-stocks-etf-defied-p-140500563.html',
#   'providerPublishTime': 1698847500,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/6COEXeClwmeomi7GJBtQ_A--~B/aD0zNTI7dz02MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/0ebfee36c934c6a8c2ac1c4c77316a8e',
#      'width': 620,
#      'height': 352,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MWGSSC2CjnahYEmV45.7QQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/0ebfee36c934c6a8c2ac1c4c77316a8e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', 'SPY', 'PANW', 'CBOE', 'PGR']},
#  {'uuid': 'bcf8b60b-b176-428a-88b9-cbdc85716bfd',
#   'title': 'Stock market news today: US stocks close higher in countdown to Fed',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-today-us-stocks-close-higher-in-countdown-to-fed-200111061.html',
#   'providerPublishTime': 1698782471,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cXBtDPIwEmFx6P6ujmS4ng--~B/aD0zNTI0O3c9NTI4NjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-10/b3eae410-77dc-11ee-af37-05fa40101868',
#      'width': 5286,
#      'height': 3524,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/9G9v7JZIGW5EKVu0MLcGPA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-10/b3eae410-77dc-11ee-af37-05fa40101868',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'QQQ', '^GSPC', '^IXIC', 'SPY']}]

# %%
yf.pdr_override()

y_symbols = ['^GSPC', 'ES=F', 'NQ=F', 'YM=F', '^RUT', '^DJT', '^GDAXI', '^N225', '^SSMI', '^STOXX50E', '^FCHI', '^GSPTSE', '^HSI', '000001.SS', '^KS11', '^NSEI', '^AXJO']
stocks = ['^SPX']

# %%
startdate = datetime.datetime(2020,3,16)
today = date.today()
enddate = today

# %%
indices = web.get_data_yahoo(y_symbols, start=startdate, end=enddate)
stocks = web.get_data_yahoo(stocks, start=startdate, end=enddate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 indices = web.get_data_yahoo(y_symbols, start=startdate, end=enddate)
#       2 stocks = web.get_data_yahoo(stocks, start=startdate, end=enddate)
#
# NameError: name 'web' is not defined

# %%
stocks

# %%
aapl.history(period='1mo')

# %%
aapl.get_shares_full(start="2022-01-01", end=None)

# %%
opt_df = aapl.option_chain('2023-11-10')
call = opt_df.calls
put = opt_df.puts
put

# %%
ax = put.boxplot(return_type='axes', rot=45, figsize=(12, 6))
ax.set_xlabel("Variable")
ax.set_ylabel("Value")
ax.set_title("Boxplot of Variable Raw Values")
plt.show()

# %%
put.describe()

# %%
df_temp

# %%
aapl.options
